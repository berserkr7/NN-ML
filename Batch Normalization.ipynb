# %%
# internal covariance shift (внутренний ковариационный сдвиг)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# То есть плотность распределения меняется от слоя к слою, что негативно сказывается на обучении

# %%
# И поскольку на каждом слое у нас разные статистические распределения,
# то градиетному спуску приходитяс подстраивается

# %%
# Давайте теперь нормировать данные на каждом слое. В алгоритме Batch Normalization
# используют первые 2 статистические характеристики - математическое ожидание и дисперсию, и
# их приводят к значениям 0 и 1 соответственно

# %%
# То есть ищем матожидание и диспресию в пределах батча. В итоге получаем
# вектор Z с неулевым матожиданием и дисперсией 1.

# Но, этого недостаточно, 
# теперь нормированные величины масштабируются и смещаются

# %% [markdown]
# y_k = l*z_k + Beta, i = 1, 2, ...
#
# И только потом эта величина y подается на вход функции фактивации!

# %%
# Итак, плюсы Batch Normalization (возможные, иногда он и ухудшает):
    
# 1) Ускорение сходимости к модели обучения

# 2) бОльшая независимость обучения каждого слоя нейрона

# 3) возможность увеличения шага обучения

# 4) в некоторой степени предотвращает эффект переобучения

# 5) меньшая чувствительность к начальной инициализации весовых коэффициентов

# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'

import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.datasets import mnist         # библиотека базы выборок Mnist
from tensorflow import keras
from tensorflow.keras.layers import Dense, Flatten
from sklearn.model_selection import train_test_split
from tensorflow.keras.layers import BatchNormalization

# %%
# прописываем в модели к слою, в котором применяется

model = keras.Sequential([
    Flatten(input_shape=(28, 28, 1)),
    Dense(300, activation='relu'),
    BatchNormalization(), # ставится после слоя, к которому хотим применить
    Dense(10, activation='softmax')
])

# %%
# Стоит отметить, что в такой небольшой НС, скорее всего 
# батч нормализация даст негативный результат!
